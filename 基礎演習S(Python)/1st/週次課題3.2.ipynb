# %%
dat <- read.csv("/指導法データ.csv")
dat

# %% [markdown]
# ### 1.指導法の度数分布表

# %%
sidou<-dat$指導法
table(sidou)
# Out:
# sidou
# A B C D
# 5 5 5 5

# %% [markdown]
# ###2.心理学テストのヒストグラム

# %%
sinri <- dat$心理学テスト
hist(sinri)
# Out:
# Plot with title “Histogram of sinri”

# %% [markdown]
# ### 3.心理学テストの〜〜

# %%
summary(sinri)
print("平均値:10.2")
print("中央値:11")
#分散
var(sinri)
#標準偏差
sd(sinri)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    4.00    7.75   11.00   10.20   13.25   15.00
# [1] "平均値:10.2"
# [1] "中央値:11"
# [1] "分散"
# [1] 3.5333

# %% [markdown]
# ### 4.統計テスト1の平均

# %%
tokei <- dat$統計テスト１
mean(tokei)
# Out:
# [1] 7.6

# %% [markdown]
# ###5.心理学の偏差値

# %%
for(i in 1:length(tokei)){
  print((tokei[i]-mean(tokei))/sd(tokei)*10+50)
}
# Out:
# [1] 45.2414
# [1] 57.13791
# [1] 45.2414
# [1] 57.13791
# [1] 48.21552
# [1] 36.31901
# [1] 42.26727
# [1] 54.16378
# [1] 36.31901
# [1] 36.31901
# [1] 60.11204
# [1] 45.2414
# [1] 60.11204
# [1] 54.16378
# [1] 77.9568
# [1] 42.26727
# [1] 51.18965
# [1] 48.21552
# [1] 48.21552
# [1] 54.16378
