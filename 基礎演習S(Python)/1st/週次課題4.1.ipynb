# %%
# 「IPA」フォントをインストール
system("apt-get install -y fonts-ipafont")
# フォント一覧を表示
# systemfonts::system_fonts()
# グラフィクスパラメータのフォントファミリーをIPAGothicとする
par(family="IPAGothic")

# %% [markdown]
# ### 1. 散布図

# %%
data<-read.csv("/指導法データ.csv")
plot(data$心理学テスト, data$統計テスト1)
# Out:
# plot without title

# %% [markdown]
# ### 2. 共分散、相関係数

# %%
print("共分散")  
cov(data$心理学テスト,data$`統計テスト１`)
print("相関係数")
cor(data$`心理学テスト`, data$`統計テスト１`)
# Out:
# [1] "共分散"
# [1] 5.347368
# [1] "相関係数"
# [1] 0.4501106

# %% [markdown]
# ### 3. クロス集計

# %%
数学<-data$数学
統計<-data$統計
table(数学, 統計)
# Out:
#       統計
# 数学 好き 嫌い
#   好き    4    2
#   嫌い    4   10
