# %%
# 「IPA」フォントをインストール
system("apt-get install -y fonts-ipafont")
# フォント一覧を表示
# systemfonts::system_fonts()
# グラフィクスパラメータのフォントファミリーをIPAGothicとする
par(family="IPAGothic")

# %%
data<-read.csv("/指導法データ.csv")
a<-data$心理学テスト
t.test(a, mu=16) #両側検定
# Out:
# 	One Sample t-test
#
# data:  a
# t = -7.3411, df = 19, p-value = 5.863e-07
# alternative hypothesis: true mean is not equal to 16
# 95 percent confidence interval:
#   8.546365 11.853635
# sample estimates:
# mean of x
#      10.2

# %% [markdown]
# P値が有意水準（0.05）を超えるので、帰無仮説が棄却されない。よって、心理学テストの得点が平均＝20-4の正規分布であるという帰無仮説が成り立たない。
